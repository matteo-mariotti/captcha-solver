# %%
import cv2
import pandas as pd
import numpy as np
import seaborn
import matplotlib.pyplot as plt
import diplib as dip

# %%
path1 = '../samples/226md.png'

# %%
def plot_ (img1):
    plt.figure(figsize=(20,5))

    plt.subplot(1,2,1)
    plt.imshow(img1, cmap='gray')

# %%
img1 = cv2.imread(path1, cv2.IMREAD_GRAYSCALE)

# %%
plot_(img1)

# %%
threas_img1 = cv2.adaptiveThreshold(img1, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 175, 25)

# %%
plot_(threas_img1)

# %%
close_img1 = cv2.morphologyEx(threas_img1, cv2.MORPH_CLOSE, np.ones((5,2), np.uint8))

# %%
plot_(close_img1)

# %%
dilate_img1 = cv2.dilate(close_img1, np.ones((2,2), np.uint8), iterations=1)

# %%
plot_(dilate_img1)

# %%
gauss_img1 = cv2.GaussianBlur(dilate_img1, (1,1), 0)

# %%
plot_(gauss_img1)

# %%
cv2.rectangle(gauss_img1, (30,12), (50,49), 0, 1)
cv2.rectangle(gauss_img1, (50,12), (70,49), 0, 1)
cv2.rectangle(gauss_img1, (70,12), (90,49), 0, 1)
cv2.rectangle(gauss_img1, (90,12), (110,49),0, 1)
cv2.rectangle(gauss_img1, (110,12),(130,49),0, 1)
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
plot_(gauss_img1)
